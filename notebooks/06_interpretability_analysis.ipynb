# %% [markdown]
# <a href="https://colab.research.google.com/github/kaves29/kan-vs-mlp-rl-research/blob/main/notebooks/06_interpretability_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Interpretability Analysis — Dominant Spline Extraction
## Purpose
Extract and visualize dominant spline functions from
the best performing KAN agent. Annotate each spline
in plain English describing its role in the agent's
decision making policy.
## This Is The Showstopper
The visual output of this notebook is the centerpiece
of the ISEF display board.
## Status: NOT STARTED — Target October 2026
